# %% [markdown]
# # setup compute

# %%
# !pip install prefect[dask] dask-jobqueue
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting prefect[dask]
#   Downloading prefect-2.19.6-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 83.2 MB/s eta 0:00:00:00:0100:01
# Collecting dask-jobqueue
#   Downloading dask_jobqueue-0.8.5-py2.py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 2.4 MB/s eta 0:00:00
# Collecting coolname<3.0.0,>=1.0.4
#   Downloading coolname-2.2.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (2022.11.0)
# Requirement already satisfied: httpx[http2]!=0.23.2,>=0.23 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from prefect[dask]) (0.27.0)
# Requirement already satisfied: itsdangerous in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (2.1.2)
# Collecting orjson<4.0,>=3.7
#   Downloading orjson-3.10.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 8.1 MB/s eta 0:00:00
# Collecting apprise<2.0.0,>=1.1.0
#   Downloading apprise-1.8.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.8 MB/s eta 0:00:00
# Collecting asyncpg>=0.23
#   Downloading asyncpg-0.29.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 77.1 MB/s eta 0:00:00:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (2.8.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (6.0)
# Collecting jinja2-humanize-extension>=0.4.0
#   Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl (4.8 kB)
# Requirement already satisfied: pytz<2025,>=2021.1 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (2022.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (4.17.1)
# Collecting pendulum<3.0
#   Downloading pendulum-2.1.2-cp39-cp39-manylinux1_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: pathspec>=0.8.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (0.11.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (5.1.0)
# Requirement already satisfied: pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (1.10.13)
# Collecting rfc3339-validator<0.2.0,>=0.1.4
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting graphviz>=0.20.1
#   Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 1.8 MB/s eta 0:00:00
# Collecting importlib-resources<6.2.0,>=6.1.3
#   Downloading importlib_resources-6.1.3-py3-none-any.whl (34 kB)
# Collecting kubernetes<30.0.0,>=24.2.0
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.2 MB/s eta 0:00:00
# Collecting readchar<5.0.0,>=4.0.0
#   Downloading readchar-4.1.0-py3-none-any.whl (9.1 kB)
# Collecting typer!=0.12.2,<0.13.0,>=0.12.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.6 MB/s eta 0:00:00
# Collecting pydantic-core<3.0.0,>=2.12.0
#   Downloading pydantic_core-2.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.3 MB/s eta 0:00:00:00:01
# Collecting humanize>=4.9.0
#   Downloading humanize-4.9.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: rich<14.0,>=11.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (13.6.0)
# Collecting asgi-lifespan<3.0,>=1.0
#   Downloading asgi_lifespan-2.1.0-py3-none-any.whl (10 kB)
# Collecting cachetools<6.0,>=5.3
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting websockets<13.0,>=10.4
#   Downloading websockets-12.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.0/130.0 kB 10.6 MB/s eta 0:00:00
# Collecting ujson<6.0.0,>=5.8.0
#   Downloading ujson-5.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.0 MB/s eta 0:00:00
# Collecting griffe>=0.20.0
#   Downloading griffe-0.47.0-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 kB 8.6 MB/s eta 0:00:00
# Collecting aiosqlite>=0.17.0
#   Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Collecting sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22
#   Downloading SQLAlchemy-2.0.31-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 62.7 MB/s eta 0:00:00:00:01
# Collecting uvicorn<0.29.0,>=0.14.0
#   Downloading uvicorn-0.28.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.1 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (38.0.4)
# Collecting jsonpatch<2.0,>=1.32
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting python-slugify<9.0,>=5.0
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Collecting typing-extensions<5.0.0,>=4.5.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging<24.3,>=21.3 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (21.3)
# Requirement already satisfied: click<8.2,>=8.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (8.1.3)
# Collecting alembic<2.0.0,>=1.7.5
#   Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 13.9 MB/s eta 0:00:00
# Collecting dateparser<2.0.0,>=1.1.1
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from prefect[dask]) (1.0.5)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (3.1.2)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (2.2.0)
# Collecting python-multipart>=0.0.7
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: toml>=0.10.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (0.10.2)
# Collecting docker>=4.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 7.8 MB/s eta 0:00:00
# Collecting anyio<4.0.0,>=3.7.1
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from prefect[dask]) (1.3.0)
# Collecting croniter<3.0.0,>=1.0.12
#   Downloading croniter-2.0.5-py2.py3-none-any.whl (20 kB)
# Collecting ruamel.yaml>=0.17.0
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 6.1 MB/s eta 0:00:00
# Collecting prefect-dask
#   Downloading prefect_dask-0.2.9-py3-none-any.whl (15 kB)
# Requirement already satisfied: dask>=2022.02.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from dask-jobqueue) (2022.11.1)
# Requirement already satisfied: distributed>=2022.02.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from dask-jobqueue) (2022.11.1)
# Requirement already satisfied: Mako in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from alembic<2.0.0,>=1.7.5->prefect[dask]) (1.2.4)
# Requirement already satisfied: idna>=2.8 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from anyio<4.0.0,>=3.7.1->prefect[dask]) (3.4)
# Requirement already satisfied: exceptiongroup in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from anyio<4.0.0,>=3.7.1->prefect[dask]) (1.0.4)
# Requirement already satisfied: requests in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from apprise<2.0.0,>=1.1.0->prefect[dask]) (2.28.1)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from apprise<2.0.0,>=1.1.0->prefect[dask]) (2024.6.2)
# Requirement already satisfied: markdown in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from apprise<2.0.0,>=1.1.0->prefect[dask]) (3.4.1)
# Requirement already satisfied: async-timeout>=4.0.3 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from asyncpg>=0.23->prefect[dask]) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from cryptography>=36.0.1->prefect[dask]) (1.15.1)
# Requirement already satisfied: partd>=0.3.10 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from dask>=2022.02.0->dask-jobqueue) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from dask>=2022.02.0->dask-jobqueue) (0.12.0)
# Collecting regex!=2019.02.19,!=2021.8.27
#   Downloading regex-2024.5.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 28.8 MB/s eta 0:00:00
# Collecting tzlocal
#   Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: locket>=1.0.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (5.9.4)
# Requirement already satisfied: msgpack>=0.6.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (1.0.4)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (6.1)
# Requirement already satisfied: urllib3 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (1.26.13)
# Requirement already satisfied: zict>=0.1.3 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue) (2.2.0)
# Requirement already satisfied: colorama>=0.4 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from griffe>=0.20.0->prefect[dask]) (0.4.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from httpcore<2.0.0,>=1.0.5->prefect[dask]) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect[dask]) (4.1.0)
# Requirement already satisfied: zipp>=0.5 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from importlib-metadata>=4.4->prefect[dask]) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from jinja2<4.0.0,>=3.0.0->prefect[dask]) (2.1.1)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.4.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect[dask]) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect[dask]) (0.19.2)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 8.2 MB/s eta 0:00:00
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.30.0-py2.py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from kubernetes<30.0.0,>=24.2.0->prefect[dask]) (1.16.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from kubernetes<30.0.0,>=24.2.0->prefect[dask]) (1.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from packaging<24.3,>=21.3->prefect[dask]) (3.0.9)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 18.0 MB/s eta 0:00:00
# Collecting email-validator>=1.0.3
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from rich<14.0,>=11.0->prefect[dask]) (2.13.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from rich<14.0,>=11.0->prefect[dask]) (3.0.0)
# Collecting ruamel.yaml.clib>=0.2.7
#   Downloading ruamel.yaml.clib-0.2.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (562 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.1/562.1 kB 20.1 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.3-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (614 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.3/614.3 kB 25.6 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pycparser in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect[dask]) (2.21)
# Requirement already satisfied: dnspython>=2.0.0 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from email-validator>=1.0.3->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect[dask]) (2.2.1)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: hyperframe<7,>=6.0 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect[dask]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /sdf/home/s/sanjeev/.local/lib/python3.9/site-packages (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect[dask]) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=11.0->prefect[dask]) (0.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from requests->apprise<2.0.0,>=1.1.0->prefect[dask]) (2.1.1)
# Requirement already satisfied: heapdict in /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages (from zict>=0.1.3->distributed>=2022.02.0->dask-jobqueue) (1.0.1)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: text-unidecode, coolname, websockets, ujson, tzlocal, typing-extensions, shellingham, ruamel.yaml.clib, rfc3339-validator, regex, readchar, pytzdata, python-slugify, python-multipart, pyasn1, orjson, oauthlib, jsonpointer, importlib-resources, humanize, griffe, greenlet, graphviz, email-validator, cachetools, asyncpg, asgi-lifespan, anyio, uvicorn, sqlalchemy, ruamel.yaml, rsa, requests-oauthlib, pydantic-core, pyasn1-modules, pendulum, jsonpatch, jinja2-humanize-extension, docker, dateparser, croniter, aiosqlite, typer, google-auth, apprise, alembic, kubernetes, dask-jobqueue, prefect, prefect-dask
# Successfully installed aiosqlite-0.20.0 alembic-1.13.2 anyio-3.7.1 apprise-1.8.0 asgi-lifespan-2.1.0 asyncpg-0.29.0 cachetools-5.3.3 coolname-2.2.0 croniter-2.0.5 dask-jobqueue-0.8.5 dateparser-1.2.0 docker-7.1.0 email-validator-2.2.0 google-auth-2.30.0 graphviz-0.20.3 greenlet-3.0.3 griffe-0.47.0 humanize-4.9.0 importlib-resources-6.1.3 jinja2-humanize-extension-0.4.0 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-29.0.0 oauthlib-3.2.2 orjson-3.10.5 pendulum-2.1.2 prefect-2.19.6 prefect-dask-0.2.9 pyasn1-0.6.0 pyasn1-modules-0.4.0 pydantic-core-2.20.0 python-multipart-0.0.9 python-slugify-8.0.4 pytzdata-2020.1 readchar-4.1.0 regex-2024.5.15 requests-oauthlib-2.0.0 rfc3339-validator-0.1.4 rsa-4.9 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 shellingham-1.5.4 sqlalchemy-2.0.31 text-unidecode-1.3 typer-0.12.3 typing-extensions-4.12.2 tzlocal-5.2 ujson-5.10.0 uvicorn-0.28.1 websockets-12.0

# %%
#pip install prefect[dask] dask-jobqueue
# prefect config set PREFECT_API_URL="https://ard-modeling-service.slac.stanford.edu/api" 

from dask.distributed import Client
from dask_jobqueue import SLURMCluster

# Simplify SLURMCluster parameters to basic working configuration
cluster_kwargs = {
    "cores": 12,  
    "memory": "10GB",  # Correct spacing
    "shebang": "#!/bin/bash",
    "account": "facet",
    "walltime": "00:10:00",
    "job_script_prologue": ["source ~/.bashrc"],
    # Only basic directives, add more as needed and test each step
    "job_extra_directives": ["-q debug", "--partition=milano", "--qos=preemptable"],
}

# %%
cluster = SLURMCluster(**cluster_kwargs)
print(cluster.job_script())
# Out:
# #!/bin/bash
#
# #SBATCH -J dask-worker
# #SBATCH -A facet
# #SBATCH -n 1
# #SBATCH --cpus-per-task=12
# #SBATCH --mem=10G
# #SBATCH -t 00:10:00
# #SBATCH -q debug
# #SBATCH --partition=milano
# #SBATCH --qos=preemptable
# source ~/.bashrc
# /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/bin/python -m distributed.cli.dask_worker tcp://172.24.48.175:46761 --name dummy-name --nthreads 3 --memory-limit 2.33GiB --nworkers 4 --nanny --death-timeout 60

# %%
slurm_jobs = 1
cluster.scale(jobs=slurm_jobs)
client = Client(cluster)
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-24' coro=<_wrap_awaitable() done, defined at /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/tasks.py:681> exception=FileNotFoundError(2, 'No such file or directory')>
# Traceback (most recent call last):
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/tasks.py", line 688, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/distributed/deploy/spec.py", line 64, in _
#     await self.start()
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 426, in start
#     out = await self._submit_job(fn)
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 409, in _submit_job
#     return await self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 494, in _call
#     proc = await asyncio.create_subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/subprocess.py", line 236, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_events.py", line 1676, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 197, in _make_subprocess_transport
#     transp = _UnixSubprocessTransport(self, protocol, args, shell,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_subprocess.py", line 36, in __init__
#     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 789, in _start
#     self._proc = subprocess.Popen(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 1821, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'sbatch'
# 2024-06-26 11:27:19,913 - tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <tornado.platform.asyncio.AsyncIOLoop object at 0x7fec879fd340>>, <Task finished name='Task-23' coro=<SpecCluster._correct_state_internal() done, defined at /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/distributed/deploy/spec.py:330> exception=FileNotFoundError(2, 'No such file or directory')>)
# Traceback (most recent call last):
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/distributed/deploy/spec.py", line 369, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/distributed/deploy/spec.py", line 64, in _
#     await self.start()
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 426, in start
#     out = await self._submit_job(fn)
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 409, in _submit_job
#     return await self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 494, in _call
#     proc = await asyncio.create_subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/subprocess.py", line 236, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_events.py", line 1676, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 197, in _make_subprocess_transport
#     transp = _UnixSubprocessTransport(self, protocol, args, shell,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_subprocess.py", line 36, in __init__
#     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 789, in _start
#     self._proc = subprocess.Popen(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 1821, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'sbatch'
# Task exception was never retrieved
# future: <Task finished name='Task-28' coro=<_wrap_awaitable() done, defined at /sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/tasks.py:681> exception=FileNotFoundError(2, 'No such file or directory')>
# Traceback (most recent call last):
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/tasks.py", line 688, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/site-packages/distributed/deploy/spec.py", line 64, in _
#     await self.start()
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 426, in start
#     out = await self._submit_job(fn)
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 409, in _submit_job
#     return await self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/sdf/home/s/sanjeev/.local/lib/python3.9/site-packages/dask_jobqueue/core.py", line 494, in _call
#     proc = await asyncio.create_subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/subprocess.py", line 236, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_events.py", line 1676, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 197, in _make_subprocess_transport
#     transp = _UnixSubprocessTransport(self, protocol, args, shell,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/base_subprocess.py", line 36, in __init__
#     self._start(args=args, shell=shell, stdin=stdin, stdout=stdout,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/asyncio/unix_events.py", line 789, in _start
#     self._proc = subprocess.Popen(
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/sdf/group/lcls/ds/ana/sw/conda1/inst/envs/ana-4.0.62-py3/lib/python3.9/subprocess.py", line 1821, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'sbatch'

# %% [markdown]
# # define code

# %%
# %time
@delayed
def slow_square(x):
    time.sleep(1)  # Simulate a delay
    return x * x

# Generate tasks using a for loop
tasks = [slow_square(i) for i in range(10)]

# Compute the results in parallel
results = compute(*tasks)

print("Results:", results)
# Out:
# CPU times: user 1 µs, sys: 1 µs, total: 2 µs
# Wall time: 4.53 µs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 get_ipython().run_line_magic('time', '')
# ----> 2 @delayed
#       3 def slow_square(x):
#       4     time.sleep(1)  # Simulate a delay
#       5     return x * x
#
# NameError: name 'delayed' is not defined
